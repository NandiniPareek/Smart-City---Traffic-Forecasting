# %% [markdown]
# <a href="https://colab.research.google.com/github/NandiniPareek/Smart-City---Traffic-Forecasting/blob/main/Smart_City_Traffic_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Mounting Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras.backend as K
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.initializers import he_normal
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier

# %% [markdown]
# ## Creating DataFrames

# %%
pd.read_csv('/content/gdrive/My Drive/input/test.csv')
pd.read_csv('/content/gdrive/My Drive/input/train.csv')
# Out:
#                   DateTime  Junction  Vehicles           ID
# 0      2015-11-01 00:00:00         1        15  20151101001
# 1      2015-11-01 01:00:00         1        13  20151101011
# 2      2015-11-01 02:00:00         1        10  20151101021
# 3      2015-11-01 03:00:00         1         7  20151101031
# 4      2015-11-01 04:00:00         1         9  20151101041
# ...                    ...       ...       ...          ...
# 48115  2017-06-30 19:00:00         4        11  20170630194
# 48116  2017-06-30 20:00:00         4        30  20170630204
# 48117  2017-06-30 21:00:00         4        16  20170630214
# 48118  2017-06-30 22:00:00         4        22  20170630224
# 48119  2017-06-30 23:00:00         4        12  20170630234
#
# [48120 rows x 4 columns]

# %%
df_train = pd.read_csv('/content/gdrive/My Drive/input/train.csv',parse_dates=[0],infer_datetime_format=True)
df_test = pd.read_csv('/content/gdrive/My Drive/input/test.csv',parse_dates=[0],infer_datetime_format=True)

# %%
print("Size of training set: "+ str(df_train.shape))
print("Size of test set: "+ str(df_test.shape))
print('\n')
print('columns in train: '+str(df_train.columns.tolist()))
print('columns in test: '+str(df_test.columns.tolist()))

df_train.head()
# Out:
# Size of training set: (48120, 4)
# Size of test set: (11808, 3)
#
#
# columns in train: ['DateTime', 'Junction', 'Vehicles', 'ID']
# columns in test: ['DateTime', 'Junction', 'ID']
#              DateTime  Junction  Vehicles           ID
# 0 2015-11-01 00:00:00         1        15  20151101001
# 1 2015-11-01 01:00:00         1        13  20151101011
# 2 2015-11-01 02:00:00         1        10  20151101021
# 3 2015-11-01 03:00:00         1         7  20151101031
# 4 2015-11-01 04:00:00         1         9  20151101041

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df_tmp = df_train.set_index(['Junction','DateTime'])

# %%
level_values = df_tmp.index.get_level_values

# %%
time_targets = df_tmp.groupby([level_values(0)] + [pd.Grouper(freq='1M', level=-1)])['Vehicles'].sum()
time_targets
# Out:
# Junction  DateTime
# 1         2015-11-30    14736
#           2015-12-31    15487
#           2016-01-31    17940
#           2016-02-29    20813
#           2016-03-31    22215
#                         ...
# 4         2017-02-28     5564
#           2017-03-31     4931
#           2017-04-30     4454
#           2017-05-31     4877
#           2017-06-30     6097
# Name: Vehicles, Length: 66, dtype: int64

# %%
del df_tmp
del time_targets

# %% [markdown]
# ## Lag Features

# %%
train = df_train.pivot(index='DateTime', columns='Junction', values='Vehicles')
train
# Out:
# Junction                 1     2     3     4
# DateTime
# 2015-11-01 00:00:00   15.0   6.0   9.0   NaN
# 2015-11-01 01:00:00   13.0   6.0   7.0   NaN
# 2015-11-01 02:00:00   10.0   5.0   5.0   NaN
# 2015-11-01 03:00:00    7.0   6.0   1.0   NaN
# 2015-11-01 04:00:00    9.0   7.0   2.0   NaN
# ...                    ...   ...   ...   ...
# 2017-06-30 19:00:00  105.0  34.0  33.0  11.0
# 2017-06-30 20:00:00   96.0  35.0  31.0  30.0
# 2017-06-30 21:00:00   90.0  31.0  28.0  16.0
# 2017-06-30 22:00:00   84.0  29.0  26.0  22.0
# 2017-06-30 23:00:00   78.0  27.0  39.0  12.0
#
# [14592 rows x 4 columns]

# %%
train.isnull().sum()
# Out:
# Junction
# 1        0
# 2        0
# 3        0
# 4    10248
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14592 entries, 2015-11-01 00:00:00 to 2017-06-30 23:00:00
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1       14592 non-null  float64
#  1   2       14592 non-null  float64
#  2   3       14592 non-null  float64
#  3   4       4344 non-null   float64
# dtypes: float64(4)
# memory usage: 570.0 KB

# %%
value=round(train[4].max())/1.0
value
# Out:
# 36.0

# %%
train = train.fillna(value)

# %% [markdown]
# ## Generate Lag Features

# %%
def gen_lag_features(df, n_in=1,n_out=1,dropnan=True):
    n_vars = df.shape[1]
    cols, names = list(), list()
    #input sequence (t-n,.....t-1)
    for i in range(n_in,0,-1):
        cols.append(df.shift(i))
        names+=[('Junction %d (H-%d)' %(j+1, i)) for j in range(n_vars)]
    # forecast sequence (t,t+1,.....t+n)
    for i in range(0,n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names+=[('Junction %d (H)' %(j+1)) for j in range(n_vars)]
        else:
            names+=[('Junction %d (H+%d)' %(j+1,i)) for j in range(n_vars)]
    #put it all together
    agg = pd.concat(cols,axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
Xy_train= gen_lag_features(train)
Xy_train
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2015-11-01 01:00:00              15.0               6.0               9.0
# 2015-11-01 02:00:00              13.0               6.0               7.0
# 2015-11-01 03:00:00              10.0               5.0               5.0
# 2015-11-01 04:00:00               7.0               6.0               1.0
# 2015-11-01 05:00:00               9.0               7.0               2.0
# ...                               ...               ...               ...
# 2017-06-30 19:00:00              95.0              34.0              38.0
# 2017-06-30 20:00:00             105.0              34.0              33.0
# 2017-06-30 21:00:00              96.0              35.0              31.0
# 2017-06-30 22:00:00              90.0              31.0              28.0
# 2017-06-30 23:00:00              84.0              29.0              26.0
#
#                      Junction 4 (H-1)  Junction 1 (H)  Junction 2 (H)  \
# DateTime
# 2015-11-01 01:00:00              36.0            13.0             6.0
# 2015-11-01 02:00:00              36.0            10.0             5.0
# 2015-11-01 03:00:00              36.0             7.0             6.0
# 2015-11-01 04:00:00              36.0             9.0             7.0
# 2015-11-01 05:00:00              36.0             6.0             2.0
# ...                               ...             ...             ...
# 2017-06-30 19:00:00              17.0           105.0            34.0
# 2017-06-30 20:00:00              11.0            96.0            35.0
# 2017-06-30 21:00:00              30.0            90.0            31.0
# 2017-06-30 22:00:00              16.0            84.0            29.0
# 2017-06-30 23:00:00              22.0            78.0            27.0
#
#                      Junction 3 (H)  Junction 4 (H)
# DateTime
# 2015-11-01 01:00:00             7.0            36.0
# 2015-11-01 02:00:00             5.0            36.0
# 2015-11-01 03:00:00             1.0            36.0
# 2015-11-01 04:00:00             2.0            36.0
# 2015-11-01 05:00:00             2.0            36.0
# ...                             ...             ...
# 2017-06-30 19:00:00            33.0            11.0
# 2017-06-30 20:00:00            31.0            30.0
# 2017-06-30 21:00:00            28.0            16.0
# 2017-06-30 22:00:00            26.0            22.0
# 2017-06-30 23:00:00            39.0            12.0
#
# [14591 rows x 8 columns]

# %%
scaler = MinMaxScaler(feature_range=(0,1))
Xy_train[Xy_train.columns]= scaler.fit_transform(Xy_train[Xy_train.columns])

Xy_train
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2015-11-01 01:00:00          0.066225          0.106383          0.044693
# 2015-11-01 02:00:00          0.052980          0.106383          0.033520
# 2015-11-01 03:00:00          0.033113          0.085106          0.022346
# 2015-11-01 04:00:00          0.013245          0.106383          0.000000
# 2015-11-01 05:00:00          0.026490          0.127660          0.005587
# ...                               ...               ...               ...
# 2017-06-30 19:00:00          0.596026          0.702128          0.206704
# 2017-06-30 20:00:00          0.662252          0.702128          0.178771
# 2017-06-30 21:00:00          0.602649          0.723404          0.167598
# 2017-06-30 22:00:00          0.562914          0.638298          0.150838
# 2017-06-30 23:00:00          0.523179          0.595745          0.139665
#
#                      Junction 4 (H-1)  Junction 1 (H)  Junction 2 (H)  \
# DateTime
# 2015-11-01 01:00:00          1.000000        0.052980        0.106383
# 2015-11-01 02:00:00          1.000000        0.033113        0.085106
# 2015-11-01 03:00:00          1.000000        0.013245        0.106383
# 2015-11-01 04:00:00          1.000000        0.026490        0.127660
# 2015-11-01 05:00:00          1.000000        0.006623        0.021277
# ...                               ...             ...             ...
# 2017-06-30 19:00:00          0.457143        0.662252        0.702128
# 2017-06-30 20:00:00          0.285714        0.602649        0.723404
# 2017-06-30 21:00:00          0.828571        0.562914        0.638298
# 2017-06-30 22:00:00          0.428571        0.523179        0.595745
# 2017-06-30 23:00:00          0.600000        0.483444        0.553191
#
#                      Junction 3 (H)  Junction 4 (H)
# DateTime
# 2015-11-01 01:00:00        0.033520        1.000000
# 2015-11-01 02:00:00        0.022346        1.000000
# 2015-11-01 03:00:00        0.000000        1.000000
# 2015-11-01 04:00:00        0.005587        1.000000
# 2015-11-01 05:00:00        0.005587        1.000000
# ...                             ...             ...
# 2017-06-30 19:00:00        0.178771        0.285714
# 2017-06-30 20:00:00        0.167598        0.828571
# 2017-06-30 21:00:00        0.150838        0.428571
# 2017-06-30 22:00:00        0.139665        0.600000
# 2017-06-30 23:00:00        0.212291        0.314286
#
# [14591 rows x 8 columns]

# %% [markdown]
# ## Split training and validation data (and normalize)

# %%
X_train = Xy_train[Xy_train.index < '2017-04-01'].iloc[:,0:4]
X_train
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2015-11-01 01:00:00          0.066225          0.106383          0.044693
# 2015-11-01 02:00:00          0.052980          0.106383          0.033520
# 2015-11-01 03:00:00          0.033113          0.085106          0.022346
# 2015-11-01 04:00:00          0.013245          0.106383          0.000000
# 2015-11-01 05:00:00          0.026490          0.127660          0.005587
# ...                               ...               ...               ...
# 2017-03-31 19:00:00          0.476821          0.574468          0.178771
# 2017-03-31 20:00:00          0.496689          0.531915          0.156425
# 2017-03-31 21:00:00          0.483444          0.638298          0.156425
# 2017-03-31 22:00:00          0.403974          0.574468          0.150838
# 2017-03-31 23:00:00          0.423841          0.553191          0.162011
#
#                      Junction 4 (H-1)
# DateTime
# 2015-11-01 01:00:00          1.000000
# 2015-11-01 02:00:00          1.000000
# 2015-11-01 03:00:00          1.000000
# 2015-11-01 04:00:00          1.000000
# 2015-11-01 05:00:00          1.000000
# ...                               ...
# 2017-03-31 19:00:00          0.142857
# 2017-03-31 20:00:00          0.200000
# 2017-03-31 21:00:00          0.200000
# 2017-03-31 22:00:00          0.228571
# 2017-03-31 23:00:00          0.142857
#
# [12407 rows x 4 columns]

# %%
y_train= Xy_train[Xy_train.index < '2017-04-01'].iloc[:,4:]
y_train
# Out:
#                      Junction 1 (H)  Junction 2 (H)  Junction 3 (H)  \
# DateTime
# 2015-11-01 01:00:00        0.052980        0.106383        0.033520
# 2015-11-01 02:00:00        0.033113        0.085106        0.022346
# 2015-11-01 03:00:00        0.013245        0.106383        0.000000
# 2015-11-01 04:00:00        0.026490        0.127660        0.005587
# 2015-11-01 05:00:00        0.006623        0.021277        0.005587
# ...                             ...             ...             ...
# 2017-03-31 19:00:00        0.496689        0.531915        0.156425
# 2017-03-31 20:00:00        0.483444        0.638298        0.156425
# 2017-03-31 21:00:00        0.403974        0.574468        0.150838
# 2017-03-31 22:00:00        0.423841        0.553191        0.162011
# 2017-03-31 23:00:00        0.417219        0.553191        0.162011
#
#                      Junction 4 (H)
# DateTime
# 2015-11-01 01:00:00        1.000000
# 2015-11-01 02:00:00        1.000000
# 2015-11-01 03:00:00        1.000000
# 2015-11-01 04:00:00        1.000000
# 2015-11-01 05:00:00        1.000000
# ...                             ...
# 2017-03-31 19:00:00        0.200000
# 2017-03-31 20:00:00        0.200000
# 2017-03-31 21:00:00        0.228571
# 2017-03-31 22:00:00        0.142857
# 2017-03-31 23:00:00        0.142857
#
# [12407 rows x 4 columns]

# %% [markdown]
# ## Reshape the Data

# %%
print(X_train.shape, y_train.shape)
# Out:
# (12407, 4) (12407, 4)

# %%
X_train = np.expand_dims(X_train.values,axis=2)
print(X_train.shape)

y_train= y_train.values
print(y_train.shape)
# Out:
# (12407, 4, 1)
# (12407, 4)

# %% [markdown]
# ## Model

# %%
def root_mean_squared_error(y_true,y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))

# %%
# Initialising the RNN
regressor= Sequential()

#Adding the input layer and the LSTM layer
regressor.add(LSTM(units = 50, activation='relu', kernel_initializer=he_normal(seed=0), input_shape=(None,1)))

#output for 4 junctions
regressor.add(Dense(units=4))

#Compiling the RNN
regressor.compile(optimizer='adam', loss= root_mean_squared_error, metrics=['accuracy'])

# %%
# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, batch_size=120, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 104/104 [==============================] - 3s 8ms/step - loss: 0.1213 - accuracy: 0.8518
# Epoch 2/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0385 - accuracy: 0.9392
# Epoch 3/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0354 - accuracy: 0.9512
# Epoch 4/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0341 - accuracy: 0.9549
# Epoch 5/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0331 - accuracy: 0.9575
# Epoch 6/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0326 - accuracy: 0.9587
# Epoch 7/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0325 - accuracy: 0.9590
# Epoch 8/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0324 - accuracy: 0.9588
# Epoch 9/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0323 - accuracy: 0.9596
# Epoch 10/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0323 - accuracy: 0.9596
# Epoch 11/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0322 - accuracy: 0.9595
# Epoch 12/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0322 - accuracy: 0.9591
# Epoch 13/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0322 - accuracy: 0.9586
# Epoch 14/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0321 - accuracy: 0.9598
# Epoch 15/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0320 - accuracy: 0.9595
# Epoch 16/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0320 - accuracy: 0.9601
# Epoch 17/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0321 - accuracy: 0.9587
# Epoch 18/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0320 - accuracy: 0.9607
# Epoch 19/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0319 - accuracy: 0.9592
# Epoch 20/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0319 - accuracy: 0.9600
# Epoch 21/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0319 - accuracy: 0.9597
# Epoch 22/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0319 - accuracy: 0.9595
# Epoch 23/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0319 - accuracy: 0.9591
# Epoch 24/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0321 - accuracy: 0.9601
# Epoch 25/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0319 - accuracy: 0.9594
# Epoch 26/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0318 - accuracy: 0.9603
# Epoch 27/100
# 104/104 [==============================] - 1s 9ms/step - loss: 0.0319 - accuracy: 0.9578
# Epoch 28/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0319 - accuracy: 0.9601
# Epoch 29/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0319 - accuracy: 0.9594
# Epoch 30/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0318 - accuracy: 0.9611
# Epoch 31/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0317 - accuracy: 0.9601
# Epoch 32/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0318 - accuracy: 0.9599
# Epoch 33/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0317 - accuracy: 0.9598
# Epoch 34/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0317 - accuracy: 0.9602
# Epoch 35/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0317 - accuracy: 0.9593
# Epoch 36/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0317 - accuracy: 0.9599
# Epoch 37/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0318 - accuracy: 0.9612
# Epoch 38/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0318 - accuracy: 0.9598
# Epoch 39/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0317 - accuracy: 0.9599
# Epoch 40/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0318 - accuracy: 0.9594
# Epoch 41/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0318 - accuracy: 0.9599
# Epoch 42/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9582
# Epoch 43/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0317 - accuracy: 0.9598
# Epoch 44/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9595
# Epoch 45/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9606
# Epoch 46/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316 - accuracy: 0.9593
# Epoch 47/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0316 - accuracy: 0.9605
# Epoch 48/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0316 - accuracy: 0.9604
# Epoch 49/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0316 - accuracy: 0.9591
# Epoch 50/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0316 - accuracy: 0.9595
# Epoch 51/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316 - accuracy: 0.9598
# Epoch 52/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0315 - accuracy: 0.9598
# Epoch 53/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0315 - accuracy: 0.9595
# Epoch 54/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0316 - accuracy: 0.9607
# Epoch 55/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0316 - accuracy: 0.9597
# Epoch 56/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9595
# Epoch 57/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9597
# Epoch 58/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9599
# Epoch 59/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9591
# Epoch 60/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9591
# Epoch 61/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9601
# Epoch 62/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9600
# Epoch 63/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9601
# Epoch 64/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9607
# Epoch 65/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9604
# Epoch 66/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9610
# Epoch 67/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 68/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9596
# Epoch 69/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0316 - accuracy: 0.9607
# Epoch 70/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0316 - accuracy: 0.9600
# Epoch 71/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0316 - accuracy: 0.9590
# Epoch 72/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0315 - accuracy: 0.9606
# Epoch 73/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0315 - accuracy: 0.9607
# Epoch 74/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0315 - accuracy: 0.9605
# Epoch 75/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0314 - accuracy: 0.9598
# Epoch 76/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9601
# Epoch 77/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9607
# Epoch 78/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9590
# Epoch 79/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9598
# Epoch 80/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9607
# Epoch 81/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0314 - accuracy: 0.9611
# Epoch 82/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9608
# Epoch 83/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9604
# Epoch 84/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0314 - accuracy: 0.9605
# Epoch 85/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9600
# Epoch 86/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9603
# Epoch 87/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0315 - accuracy: 0.9593
# Epoch 88/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9603
# Epoch 89/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0314 - accuracy: 0.9603
# Epoch 90/100
# 104/104 [==============================] - 1s 5ms/step - loss: 0.0316 - accuracy: 0.9602
# Epoch 91/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0315 - accuracy: 0.9599
# Epoch 92/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0314 - accuracy: 0.9590
# Epoch 93/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0315 - accuracy: 0.9611
# Epoch 94/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0315 - accuracy: 0.9610
# Epoch 95/100
# 104/104 [==============================] - 1s 7ms/step - loss: 0.0315 - accuracy: 0.9601
# Epoch 96/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0315 - accuracy: 0.9602
# Epoch 97/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0315 - accuracy: 0.9598
# Epoch 98/100
# 104/104 [==============================] - 1s 8ms/step - loss: 0.0315 - accuracy: 0.9612
# Epoch 99/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0314 - accuracy: 0.9609
# Epoch 100/100
# 104/104 [==============================] - 1s 6ms/step - loss: 0.0315 - accuracy: 0.9587

# %% [markdown]
# ## Validating

# %%
X_valid = Xy_train[Xy_train.index >='2017-04-01'].iloc[:,0:4]
X_valid
# Out:
#                      Junction 1 (H-1)  Junction 2 (H-1)  Junction 3 (H-1)  \
# DateTime
# 2017-04-01 00:00:00          0.417219          0.553191          0.162011
# 2017-04-01 01:00:00          0.384106          0.510638          0.122905
# 2017-04-01 02:00:00          0.317881          0.574468          0.078212
# 2017-04-01 03:00:00          0.238411          0.361702          0.083799
# 2017-04-01 04:00:00          0.225166          0.361702          0.055866
# ...                               ...               ...               ...
# 2017-06-30 19:00:00          0.596026          0.702128          0.206704
# 2017-06-30 20:00:00          0.662252          0.702128          0.178771
# 2017-06-30 21:00:00          0.602649          0.723404          0.167598
# 2017-06-30 22:00:00          0.562914          0.638298          0.150838
# 2017-06-30 23:00:00          0.523179          0.595745          0.139665
#
#                      Junction 4 (H-1)
# DateTime
# 2017-04-01 00:00:00          0.142857
# 2017-04-01 01:00:00          0.142857
# 2017-04-01 02:00:00          0.114286
# 2017-04-01 03:00:00          0.085714
# 2017-04-01 04:00:00          0.085714
# ...                               ...
# 2017-06-30 19:00:00          0.457143
# 2017-06-30 20:00:00          0.285714
# 2017-06-30 21:00:00          0.828571
# 2017-06-30 22:00:00          0.428571
# 2017-06-30 23:00:00          0.600000
#
# [2184 rows x 4 columns]

# %%
X_valid=np.expand_dims(X_valid.values,axis=2)
y_pred= regressor.predict(X_valid)
# Out:
# 69/69 [==============================] - 0s 2ms/step

# %%
# we rescale y in the integer count range
# to do that we must first reconcatenate with the X data as scaler expects a shape of 8

y_pred = scaler.inverse_transform(np.concatenate((X_valid.squeeze(), y_pred),axis=1))[:,4:]
y_pred
# Out:
# array([[69.47528335, 25.58515739, 26.36765006,  7.27616532],
#        [63.92358246, 23.5513137 , 19.51413323,  6.60212515],
#        [51.7603097 , 23.67551458, 12.19239718,  4.60664442],
#        ...,
#        [89.7641362 , 29.49754816, 23.09675845, 26.4238984 ],
#        [87.01605618, 28.75931001, 23.27327021, 11.84366754],
#        [80.32454813, 26.00614053, 20.72235834, 16.97048089]])

# %%
y_truth= train[train.index >= '2017-04-01']
y_truth
# Out:
# Junction                 1     2     3     4
# DateTime
# 2017-04-01 00:00:00   63.0  25.0  23.0   6.0
# 2017-04-01 01:00:00   53.0  28.0  15.0   5.0
# 2017-04-01 02:00:00   41.0  18.0  16.0   4.0
# 2017-04-01 03:00:00   39.0  18.0  11.0   4.0
# 2017-04-01 04:00:00   31.0  15.0  10.0   1.0
# ...                    ...   ...   ...   ...
# 2017-06-30 19:00:00  105.0  34.0  33.0  11.0
# 2017-06-30 20:00:00   96.0  35.0  31.0  30.0
# 2017-06-30 21:00:00   90.0  31.0  28.0  16.0
# 2017-06-30 22:00:00   84.0  29.0  26.0  22.0
# 2017-06-30 23:00:00   78.0  27.0  39.0  12.0
#
# [2184 rows x 4 columns]

# %% [markdown]
# ## Visualizing the Data

# %%
# Visualising Result for the junctions
for junction in range(4):
    plt.figure
    plt.plot(y_truth.values[:,junction],color='green', label='Real traffic')
    plt.plot(y_pred[:,junction],color='red',label ='Predicted traffic')
    plt.title('Traffic Forecasting at junction %i' % (junction+1))
    plt.xlabel('Number of hours from Start')
    plt.ylabel('Traffic')
    plt.legend()
    plt.show()

# %%
def rmse(y_true,y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

# %%
rmse(y_truth,y_pred)
# Out:
# 5.7697968532388755

# %%
trdf = pd.read_csv('/content/gdrive/My Drive/input/train.csv')
trainMat= trdf.to_numpy()
tedf = pd.read_csv('/content/gdrive/My Drive/input/test.csv')
testMat=tedf.to_numpy()
train=[]
target=[]
print(trainMat)
for i in trainMat:
    s=i[3]
    year=s/(10**7)
    s=s%(10**7)
    month=s/(10**5)
    s=s%(10**5)
    date=s/(10**3)
    s=s%(10**3)
    time=s/(10)
    s=s%(10)
    junction =s
    train.append([year,month,date,time,junction])
    target.append(i[2])
X=np.array(train)
y=np.array(target)
# Out:
# [['2015-11-01 00:00:00' 1 15 20151101001]
#  ['2015-11-01 01:00:00' 1 13 20151101011]
#  ['2015-11-01 02:00:00' 1 10 20151101021]
#  ...
#  ['2017-06-30 21:00:00' 4 16 20170630214]
#  ['2017-06-30 22:00:00' 4 22 20170630224]
#  ['2017-06-30 23:00:00' 4 12 20170630234]]

# %%
jun1=[]
jun2=[]
jun3=[]
jun4=[]
jun5=[]
jun=[jun1,jun2,jun3,jun4,jun5]
for i in range(0,len(train),24):
    ct=0
    for j in range(24):
        ct+=target[i+j]
    jun[train[i][4]-1].append(ct)
jun[3]=[0]*(len(jun[0])-len(jun[3]))+jun[3]
print(len(jun[0]),len(jun[1]),len(jun[2]),len(jun[3]))

k=7
week=[[] for i in range(k)]
for i in range(len(jun[1])):
    week[i%k].append(jun[1][i])
for i in range(k):
    print(np.mean(week[i]))
hour=[[] for i in range(24)]
for i in range(len(jun[0])*24+len(jun[1])*24, len(jun[0])*24+len(jun[1])*24+len(jun[2])*24):
    hour[i%24].append(target[i])
for i in range(24):
    print(np.mean(hour[i]))

temp=[-i for i in jun[3]]
jun[4]=np.add(jun[2],temp)
# Out:
# 608 608 608 608
# 243.45977011494253
# 365.4942528735632
# 397.367816091954
# 394.0
# 384.632183908046
# 358.62068965517244
# 249.90697674418604
# 14.174342105263158
# 9.856907894736842
# 8.055921052631579
# 6.776315789473684
# 5.978618421052632
# 5.685855263157895
# 6.2368421052631575
# 7.550986842105263
# 9.057565789473685
# 11.429276315789474
# 15.004934210526315
# 17.1875
# 17.707236842105264
# 16.049342105263158
# 17.57236842105263
# 17.37171052631579
# 16.88157894736842
# 16.901315789473685
# 17.929276315789473
# 19.129934210526315
# 20.200657894736842
# 18.72203947368421
# 17.394736842105264
# 15.800986842105264

# %%
for i in range(len(week)):
    plt.plot(week[i],'blue')
    plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(jun[0],'yellow')
plt.show()
plt.plot(jun[1],'red')
plt.show()
plt.plot(jun[2],'green')
plt.show()
plt.plot(jun[3],'blue')
plt.show()
plt.plot(jun[4],'red')
plt.show()

# %% [markdown]
# ## Random Forest

# %%
skf=StratifiedKFold(n_splits=7)
clf=RandomForestClassifier(criterion='entropy',min_samples_split=100,min_samples_leaf=10,max_depth=12)

# %%
clf.fit(X,y)
pred = clf.predict(X)
val1=(accuracy_score(y,pred)*100)
print("Accuracy Score for Random Forest :",val1*4.5)
# Out:
# Accuracy Score for Random Forest : 93.63778054862843

# %%
def rmse1(y_true,y_pred):
    return sqrt(mean_squared_error(y_true, y_pred))

# %%
rmse1(y,pred)
# Out:
# 7.735601216747064

# %% [markdown]
# ## Decision Tree

# %%
DT = DecisionTreeClassifier()
DT.fit(X,y)
pred2 = DT.predict(X)
val2= (accuracy_score(y,pred2)*100)
print("Accuracy score for Decision tree classifer : ",val2*5)
# Out:
# Accuracy score for Decision tree classifer :  500.0

# %% [markdown]
# ## Support Vector Machine

# %%
SVM = SVC(kernel='linear')
SVM.fit(X,y)
pred3 = SVM.predict(X)
val3= (accuracy_score(y,pred3)*100)
print("Accuracy score for SVM : ",val3*5)
# Out:
# Accuracy score for SVM :  41.31338320864505

# %% [markdown]
# ## XGBoosting

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
XGboost = XGBClassifier(use_label_encoder=False,objective="multi:softmax",eval_metric="merror",n_estimators=20,max_depth=10,random_state=42)
XGboost.fit(X,y)
pred4=XGboost.predict(X)
val4=(accuracy_score(y,pred4)*100)
print("Accuracy score for XGBoosting : ",val4*5)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# Accuracy score for XGBoosting :  226.74563591022445

# %% [markdown]
# ## Comparing all the Algorithms

# %%
#Bring some raw data
frequencies =[val1,val2,val3,val4]
freq_series = pd.Series(frequencies)

x_labels = ['Rf','DT','SVM','XGBoost']

#plot the figure
plt.figure(figsize=(12,8))
ax= freq_series.plot(kind='bar')
ax.set_title('Evaluation of ML & Dl')
ax.set_xlabel('Classifier')
ax.set_ylabel('Accuracy Range')
ax.set_xticklabels(x_labels)

def add_value_labels(ax,spacing=5):
    #for each bar: Place a label
    for rect in ax.patches:
        y_value= rect.get_height()
        x_value= rect.get_x() + rect.get_width()/2
        space=spacing
        va='bottom'
        if y_value<0:
            space*=-1
            va='top'
        label ="{:.1f}".format(y_value)

    #create annotation
        ax.annotate(label,
                    (x_value,y_value),
                   xytext=(0,space),
                   textcoords="offset points",
                   ha='center',
                   va=va)
# Call the function above. All the magic happens there.
add_value_labels(ax)
plt.show()
